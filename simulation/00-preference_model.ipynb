# %% [markdown]
# # Creating a preference model
#
#
# For the simulation process, we'll first develop a simple recommender system that will fill the rating matrix from a given dataset. This will act as a **frozen preferences model**

# %%
import surprise as srs
import pandas as pd
from tqdm import tqdm

# %%
from surprise import accuracy

# %%
from surprise import Dataset, Reader
from surprise.model_selection import train_test_split, GridSearchCV
from surprise import SVDpp, NMF, KNNBasic

# %%
import sys
import os
from pathlib import Path

# %%
sys.path.append('..')

# %% [markdown]
# ## Loading data

# %%
from constants import ML_DATA_PATH

# %%
df = pd.read_csv(f"../{ML_DATA_PATH}")

# %%
df
# Out:
#          user  item  rating  timestamp  \
# 0           1  1193       5  978300760
# 1           1   661       3  978302109
# 2           1   914       3  978301968
# 3           1  3408       4  978300275
# 4           1  2355       5  978824291
# ...       ...   ...     ...        ...
# 1000204  6040  1091       1  956716541
# 1000205  6040  1094       5  956704887
# 1000206  6040   562       5  956704746
# 1000207  6040  1096       4  956715648
# 1000208  6040  1097       4  956715569
#
#                                           title  binarized_rating  \
# 0        One Flew Over the Cuckoo's Nest (1975)                 1
# 1              James and the Giant Peach (1996)                 0
# 2                           My Fair Lady (1964)                 0
# 3                        Erin Brockovich (2000)                 1
# 4                          Bug's Life, A (1998)                 1
# ...                                         ...               ...
# 1000204              Weekend at Bernie's (1989)                 0
# 1000205                 Crying Game, The (1992)                 1
# 1000206         Welcome to the Dollhouse (1995)                 1
# 1000207                  Sophie's Choice (1982)                 1
# 1000208       E.T. the Extra-Terrestrial (1982)                 1
#
#                                          genres
# 0                                     ['drama']
# 1             ['animation', 'child', 'musical']
# 2                        ['musical', 'romance']
# 3                                     ['drama']
# 4              ['animation', 'child', 'comedy']
# ...                                         ...
# 1000204                              ['comedy']
# 1000205             ['drama', 'romance', 'war']
# 1000206                     ['comedy', 'drama']
# 1000207                               ['drama']
# 1000208  ['child', 'drama', 'fantasy', 'scifi']
#
# [1000209 rows x 7 columns]

# %%
reader = Reader(rating_scale=(1, 5))

data = Dataset.load_from_df(df[["user", "item", "rating"]], reader)

# %%
trainset, testset = train_test_split(data, test_size=0.2)

# %% [markdown]
# ## Finding the best model

# %%
models = {
    "SVD++": SVDpp,
    "NMF": NMF,
    "knn": KNNBasic,
}

# %%
param_grid_svd = {
    'n_epochs': [10, 20],
    'lr_all': [0.002, 0.005],
    'reg_all': [0.02, 0.1]
}

param_grid_nmf = {
    'n_factors': [15, 30],
    'n_epochs': [50, 100],
    'reg_pu': [0.06, 0.1],
    'reg_qi': [0.06, 0.1]
}

param_grid_knn = {
    'k': [20, 40, 60],
    'sim_options': {
        'name': ['cosine', 'pearson'],
        'user_based': [True, False]
    }
}

# %%
model_name_to_params = {
    "SVD++": param_grid_svd,
    "NMF": param_grid_nmf,
    "knn": param_grid_knn
}

# %%
data

# %%
# %%time
performance_rows = []  

results_dfs = []

for model_name, model in tqdm(models.items(), desc="Grid Search Progress"):
    print(f"Iniciando CV para {model_name}...")
    params = model_name_to_params[model_name]
    gs = GridSearchCV(model, params, measures=["rmse"], cv=5)
    gs.fit(data)
    rmse = gs.best_score["rmse"] 
    best_params_rmse = gs.best_params["rmse"]
    print(rmse)
    row = [model_name, rmse, best_params_rmse]
    results_dfs.append(pd.DataFrame.from_dict(gs.cv_results))
    performance_rows.append(row)
performance_df = pd.DataFrame(performance_rows, columns=["model name", "best rmse", "best rmse params"])
# Out:
# Grid Search Progress:   0%|                                                                                                                                                                 | 0/3 [00:00<?, ?it/s]
# Iniciando CV para SVD++...
# Grid Search Progress:  33%|█████████████████████████████████████████████████                                                                                                  | 1/3 [1:34:57<3:09:54, 5697.21s/it]
# 0.8628435068287192
# Iniciando CV para NMF...
# Grid Search Progress:  67%|███████████████████████████████████████████████████████████████████████████████████████████████████▎                                                 | 2/3 [1:45:56<45:33, 2733.93s/it]
# 0.8853409079164438
# Iniciando CV para knn...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Grid Search Progress: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [2:13:35<00:00, 2671.79s/it]
# 0.9588723068541286
# CPU times: user 2h 13min 19s, sys: 26.4 s, total: 2h 13min 45s
# Wall time: 2h 13min 35s

# %%
results_dfs
# Out:
# [   split0_test_rmse  split1_test_rmse  split2_test_rmse  split3_test_rmse  \
#  0          0.902444          0.902579          0.903233          0.903308
#  1          0.915187          0.915296          0.916004          0.914306
#  2          0.880108          0.879219          0.880759          0.878191
#  3          0.906663          0.907038          0.906741          0.905201
#  4          0.885502          0.885571          0.887247          0.884057
#  5          0.908775          0.908803          0.910764          0.908685
#  6          0.862259          0.863868          0.863678          0.861500
#  7          0.891100          0.892113          0.891829          0.889088
#
#     split4_test_rmse  mean_test_rmse  std_test_rmse  rank_test_rmse  \
#  0          0.901003        0.902513       0.000829               5
#  1          0.914962        0.915151       0.000548               8
#  2          0.878692        0.879394       0.000932               2
#  3          0.906033        0.906335       0.000655               6
#  4          0.885222        0.885520       0.001021               3
#  5          0.909503        0.909306       0.000786               7
#  6          0.862913        0.862844       0.000883               1
#  7          0.891351        0.891096       0.001065               4
#
#     mean_fit_time  std_fit_time  mean_test_time  std_test_time  \
#  0      81.350173      0.638488       21.296124       0.322034
#  1      80.954830      0.608167       21.070110       0.361319
#  2      80.644239      0.547725       21.038789       0.262274
#  3      80.893993      0.433535       21.230847       0.440113
#  4     161.236662      0.977788       20.866409       0.270725
#  5     161.648592      1.047836       21.211567       0.606439
#  6     161.177722      1.200896       20.959731       0.334843
#  7     161.849479      0.796186       21.091794       0.294495
#
#                                                params  param_n_epochs  \
#  0  {'n_epochs': 10, 'lr_all': 0.002, 'reg_all': 0...              10
#  1  {'n_epochs': 10, 'lr_all': 0.002, 'reg_all': 0.1}              10
#  2  {'n_epochs': 10, 'lr_all': 0.005, 'reg_all': 0...              10
#  3  {'n_epochs': 10, 'lr_all': 0.005, 'reg_all': 0.1}              10
#  4  {'n_epochs': 20, 'lr_all': 0.002, 'reg_all': 0...              20
#  5  {'n_epochs': 20, 'lr_all': 0.002, 'reg_all': 0.1}              20
#  6  {'n_epochs': 20, 'lr_all': 0.005, 'reg_all': 0...              20
#  7  {'n_epochs': 20, 'lr_all': 0.005, 'reg_all': 0.1}              20
#
#     param_lr_all  param_reg_all
#  0         0.002           0.02
#  1         0.002           0.10
#  2         0.005           0.02
#  3         0.005           0.10
#  4         0.002           0.02
#  5         0.002           0.10
#  6         0.005           0.02
#  7         0.005           0.10  ,
#      split0_test_rmse  split1_test_rmse  split2_test_rmse  split3_test_rmse  \
#  0           0.915589          0.916554          0.915903          0.917416
#  1           0.914249          0.912500          0.917066          0.913401
#  2           0.915419          0.912953          0.915305          0.913888
#  3           0.915174          0.914337          0.917856          0.915817
#  4           0.888845          0.887513          0.894862          0.891501
#  5           0.889651          0.890376          0.892106          0.889198
#  6           0.889950          0.887663          0.894553          0.891913
#  7           0.894478          0.890946          0.892995          0.895564
#  8           0.956368          0.955860          0.958017          0.955939
#  9           0.919711          0.917391          0.919857          0.918820
#  10          0.918736          0.915369          0.918941          0.917295
#  11          0.908936          0.908675          0.912113          0.910070
#  12          0.884808          0.885456          0.885288          0.884296
#  13          0.883400          0.884778          0.887264          0.884216
#  14          0.885080          0.884861          0.887101          0.883648
#  15          0.889312          0.887197          0.890582          0.889201
#
#      split4_test_rmse  mean_test_rmse  std_test_rmse  rank_test_rmse  \
#  0           0.917909        0.916674       0.000879              13
#  1           0.916352        0.914714       0.001736              10
#  2           0.917945        0.915102       0.001692              11
#  3           0.918604        0.916357       0.001617              12
#  4           0.891868        0.890918       0.002557               6
#  5           0.889470        0.890160       0.001048               5
#  6           0.892218        0.891260       0.002317               7
#  7           0.896157        0.894028       0.001879               8
#  8           0.957621        0.956761       0.000890              16
#  9           0.921067        0.919369       0.001221              15
#  10          0.919987        0.918066       0.001598              14
#  11          0.912329        0.910425       0.001541               9
#  12          0.886857        0.885341       0.000859               1
#  13          0.887411        0.885414       0.001631               2
#  14          0.888057        0.885749       0.001600               3
#  15          0.891969        0.889652       0.001586               4
#
#      mean_fit_time  std_fit_time  mean_test_time  std_test_time  \
#  0        4.211072      0.142775        1.117676       0.377216
#  1        4.679583      0.465612        1.305943       0.445924
#  2        4.417020      0.357655        1.041338       0.423132
#  3        4.447556      0.294527        1.190008       0.412183
#  4        8.568267      0.348982        1.009695       0.418839
#  5        8.637063      0.724390        1.181824       0.425207
#  6        8.148353      0.221083        0.987113       0.405876
#  7        8.141385      0.180421        1.153512       0.407456
#  8        5.160835      0.107746        0.986879       0.403740
#  9        5.208554      0.188154        1.158666       0.412130
#  10       5.217061      0.180882        0.991904       0.401503
#  11       5.088906      0.030439        1.158926       0.408354
#  12      10.277291      0.108448        0.995956       0.408052
#  13      10.223807      0.118070        1.154737       0.410922
#  14      10.309275      0.169304        0.987531       0.406213
#  15      10.313117      0.254469        1.151867       0.407217
#
#                                                 params  param_n_factors  \
#  0   {'n_factors': 15, 'n_epochs': 50, 'reg_pu': 0....               15
#  1   {'n_factors': 15, 'n_epochs': 50, 'reg_pu': 0....               15
#  2   {'n_factors': 15, 'n_epochs': 50, 'reg_pu': 0....               15
#  3   {'n_factors': 15, 'n_epochs': 50, 'reg_pu': 0....               15
#  4   {'n_factors': 15, 'n_epochs': 100, 'reg_pu': 0...               15
#  5   {'n_factors': 15, 'n_epochs': 100, 'reg_pu': 0...               15
#  6   {'n_factors': 15, 'n_epochs': 100, 'reg_pu': 0...               15
#  7   {'n_factors': 15, 'n_epochs': 100, 'reg_pu': 0...               15
#  8   {'n_factors': 30, 'n_epochs': 50, 'reg_pu': 0....               30
#  9   {'n_factors': 30, 'n_epochs': 50, 'reg_pu': 0....               30
#  10  {'n_factors': 30, 'n_epochs': 50, 'reg_pu': 0....               30
#  11  {'n_factors': 30, 'n_epochs': 50, 'reg_pu': 0....               30
#  12  {'n_factors': 30, 'n_epochs': 100, 'reg_pu': 0...               30
#  13  {'n_factors': 30, 'n_epochs': 100, 'reg_pu': 0...               30
#  14  {'n_factors': 30, 'n_epochs': 100, 'reg_pu': 0...               30
#  15  {'n_factors': 30, 'n_epochs': 100, 'reg_pu': 0...               30
#
#      param_n_epochs  param_reg_pu  param_reg_qi
#  0               50          0.06          0.06
#  1               50          0.06          0.10
#  2               50          0.10          0.06
#  3               50          0.10          0.10
#  4              100          0.06          0.06
#  5              100          0.06          0.10
#  6              100          0.10          0.06
#  7              100          0.10          0.10
#  8               50          0.06          0.06
#  9               50          0.06          0.10
#  10              50          0.10          0.06
#  11              50          0.10          0.10
#  12             100          0.06          0.06
#  13             100          0.06          0.10
#  14             100          0.10          0.06
#  15             100          0.10          0.10  ,
#      split0_test_rmse  split1_test_rmse  split2_test_rmse  split3_test_rmse  \
#  0           0.988084          0.991422          0.985810          0.988856
#  1           1.007096          1.010369          1.006120          1.007021
#  2           0.972365          0.976978          0.970871          0.976006
#  3           1.017808          1.019107          1.015715          1.012465
#  4           0.975769          0.979381          0.972792          0.977199
#  5           0.998660          1.002027          0.997444          0.997864
#  6           0.960428          0.964532          0.958910          0.963591
#  7           0.995634          0.997085          0.993521          0.990484
#  8           0.971811          0.975549          0.968878          0.973479
#  9           0.999257          1.002547          0.997751          0.997823
#  10          0.957502          0.961516          0.955815          0.960134
#  11          0.988816          0.990326          0.987029          0.983775
#
#      split4_test_rmse  mean_test_rmse  std_test_rmse  rank_test_rmse  \
#  0           0.988951        0.988624       0.001800               7
#  1           1.009674        1.008056       0.001656              11
#  2           0.974410        0.974126       0.002256               4
#  3           1.019452        1.016909       0.002580              12
#  4           0.976978        0.976424       0.002157               5
#  5           1.000776        0.999354       0.001762               9
#  6           0.962291        0.961950       0.002051               2
#  7           0.996944        0.994734       0.002480               8
#  8           0.973023        0.972548       0.002196               3
#  9           1.001157        0.999707       0.001884              10
#  10          0.959396        0.958872       0.002004               1
#  11          0.990021        0.987994       0.002406               6
#
#      mean_fit_time  std_fit_time  mean_test_time  std_test_time  \
#  0        9.196215      0.050101       23.477200       0.364054
#  1        3.980905      0.033560       12.210405       0.529619
#  2       12.761474      0.076139       23.649576       0.745404
#  3        5.484871      0.028107       11.705742       0.217347
#  4        9.293241      0.063017       25.753016       0.655419
#  5        3.946070      0.038015       13.805952       0.438987
#  6       12.728665      0.063728       25.926372       0.409503
#  7        5.593125      0.073782       13.826968       0.593441
#  8        9.377251      0.041649       27.507848       0.350154
#  9        3.969842      0.025669       15.009954       0.405791
#  10      12.838360      0.042547       27.910598       0.353396
#  11       5.540841      0.025512       15.079020       0.447922
#
#                                                 params  param_k  \
#  0   {'k': 20, 'sim_options': {'name': 'cosine', 'u...       20
#  1   {'k': 20, 'sim_options': {'name': 'cosine', 'u...       20
#  2   {'k': 20, 'sim_options': {'name': 'pearson', '...       20
#  3   {'k': 20, 'sim_options': {'name': 'pearson', '...       20
#  4   {'k': 40, 'sim_options': {'name': 'cosine', 'u...       40
#  5   {'k': 40, 'sim_options': {'name': 'cosine', 'u...       40
#  6   {'k': 40, 'sim_options': {'name': 'pearson', '...       40
#  7   {'k': 40, 'sim_options': {'name': 'pearson', '...       40
#  8   {'k': 60, 'sim_options': {'name': 'cosine', 'u...       60
#  9   {'k': 60, 'sim_options': {'name': 'cosine', 'u...       60
#  10  {'k': 60, 'sim_options': {'name': 'pearson', '...       60
#  11  {'k': 60, 'sim_options': {'name': 'pearson', '...       60
#
#                             param_sim_options
#  0     {'name': 'cosine', 'user_based': True}
#  1    {'name': 'cosine', 'user_based': False}
#  2    {'name': 'pearson', 'user_based': True}
#  3   {'name': 'pearson', 'user_based': False}
#  4     {'name': 'cosine', 'user_based': True}
#  5    {'name': 'cosine', 'user_based': False}
#  6    {'name': 'pearson', 'user_based': True}
#  7   {'name': 'pearson', 'user_based': False}
#  8     {'name': 'cosine', 'user_based': True}
#  9    {'name': 'cosine', 'user_based': False}
#  10   {'name': 'pearson', 'user_based': True}
#  11  {'name': 'pearson', 'user_based': False}  ]

# %%
performance_df
# Out:
#   model name  best rmse                                   best rmse params
# 0      SVD++   0.862844  {'n_epochs': 20, 'lr_all': 0.005, 'reg_all': 0...
# 1        NMF   0.885341  {'n_factors': 30, 'n_epochs': 100, 'reg_pu': 0...
# 2        knn   0.958872  {'k': 60, 'sim_options': {'name': 'pearson', '...

# %%
performance_dfda.to_pickle("filename.pkl")

# %%
best_model = "SVD++"

# %%
best_params = {
    "n_epochs": 20,
    "lr_all": 0.005,
    "reg_all": 0.02
}

# %%
model = models[best_model](**best_params)

# %%
model

# %%
trainset

# %%
# %%time
model.fit(trainset)
# Out:
# CPU times: user 2min 40s, sys: 0 ns, total: 2min 40s
# Wall time: 2min 40s

# %%
# %%time
predictions = model.test(testset)
accuracy.rmse(predictions)
# Out:
# RMSE: 0.8623
# CPU times: user 20.4 s, sys: 215 ms, total: 20.6 s
# Wall time: 20.3 s
# 0.862336272288006

# %%
predictions[0].est
# Out:
# 4.360151192870443

# %% [markdown]
# ### Filling up the rating matrix - getting the oracle preferences

# %%
trainset = data.build_full_trainset()
model.fit(trainset)

# %%
# get all users and items with observed ratings
all_users = trainset.all_users()
all_items = trainset.all_items()

user_ids = [trainset.to_raw_uid(u) for u in all_users]
item_ids = [trainset.to_raw_iid(i) for i in all_items]


# generate every combination of user x item. 
predictions = []
for user_id in tqdm(user_ids, desc="Predicting missing ratings"):
    # get the corresponding internal id surprise uses
    surprise_internal_user_id = trainset.to_inner_uid(user_id)
    # gets the ratings by user surprise_internal_user_id 
    rated_item_ids = set([trainset.to_raw_iid(item) for item, rating in trainset.ur[surprise_internal_user_id]])
    for item_id in item_ids:
        if item_id not in rated_item_ids:
            #predict the rating
            pred = model.predict(user_id, item_id)
            predictions.append([user_id, item_id, pred])
# Out:
# Predicting missing ratings: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6040/6040 [16:47<00:00,  5.99it/s]

# %%
# Checks if every unobserved rating was, in fact, not observed
assert(all([pred[2].r_ui == None for pred in predictions]) == True)

# %%
processed_predictions = [[pred[0], pred[1], pred[2].est] for pred in predictions]

# %%
processed_predictions
# Out:
# [[1, 1357, 3.7357389162415564],
#  [1, 3068, 3.929694500361513],
#  [1, 1537, 4.269067396682991],
#  [1, 647, 3.926544101013872],
#  [1, 2194, 4.111438280570462],
#  [1, 648, 3.5954612746314893],
#  [1, 2268, 4.059232102516762],
#  [1, 2628, 3.435036182527352],
#  [1, 1103, 4.106766011031971],
#  [1, 2916, 3.8488278932750926],
#  [1, 3468, 4.2121008032853915],
#  [1, 1210, 3.7601985835531804],
#  [1, 1792, 3.50861968346447],
#  [1, 1687, 3.4310145173055466],
#  [1, 1213, 4.095027261392802],
#  [1, 3578, 4.101216121891879],
#  [1, 2881, 3.7484132816686064],
#  [1, 3030, 4.2257533806044085],
#  [1, 1217, 4.012843677084131],
#  [1, 434, 3.520605426573821],
#  [1, 2126, 3.1946214553868906],
#  [1, 3107, 3.6162405616162756],
#  [1, 3108, 3.5415755816708945],
#  [1, 3035, 4.304666115090101],
#  [1, 1253, 4.276655954082474],
#  [1, 1610, 4.139744375121878],
#  [1, 292, 3.764075566147149],
#  [1, 2236, 3.9336104216375976],
#  [1, 3071, 3.9955320848016576],
#  [1, 902, 4.042322078760355],
#  [1, 368, 3.6045228972153693],
#  [1, 1259, 4.057933857372171],
#  [1, 3147, 4.393359446696397],
#  [1, 1544, 3.5780536441859487],
#  [1, 1293, 4.1371102605014505],
#  [1, 1188, 4.186228934140736],
#  [1, 3255, 4.092332044874315],
#  [1, 3256, 3.991076338011232],
#  [1, 3257, 3.4093686433565313],
#  [1, 110, 4.194691176229017],
#  [1, 2278, 3.492599760705108],
#  [1, 2490, 3.551993456878152],
#  [1, 1834, 3.968112010440767],
#  [1, 3471, 4.162578688231737],
#  [1, 589, 4.161023050579847],
#  [1, 1690, 3.381953878798985],
#  [1, 3654, 4.090460435975651],
#  [1, 2852, 3.989137490334177],
#  [1, 1945, 4.244408926270835],
#  [1, 982, 3.8360998372958415],
#  [1, 1873, 4.008484571024203],
#  [1, 2858, 3.981573964717335],
#  [1, 1225, 4.376855558544004],
#  [1, 515, 4.0235499595213815],
#  [1, 442, 3.242841128814553],
#  [1, 2312, 4.115667018720665],
#  [1, 265, 4.0359684067889265],
#  [1, 1408, 3.9354984961639348],
#  [1, 1084, 4.2145524946772435],
#  [1, 3699, 3.839607767058538],
#  [1, 480, 4.019265048488106],
#  [1, 1442, 3.6929355913633732],
#  [1, 2067, 4.320371982066822],
#  [1, 1265, 4.021566553200604],
#  [1, 1370, 3.8660126567008493],
#  [1, 1801, 3.507160908826695],
#  [1, 1372, 3.5570710270863857],
#  [1, 2353, 3.9718789618440224],
#  [1, 3334, 4.01182832360941],
#  [1, 2427, 3.3861175792229434],
#  [1, 590, 4.316891877090398],
#  [1, 1196, 3.9465916244598103],
#  [1, 1552, 3.6360598784124756],
#  [1, 736, 3.5731756507565677],
#  [1, 1198, 4.444039647386087],
#  [1, 593, 4.487398919745578],
#  [1, 2359, 4.051811135731253],
#  [1, 95, 3.189478142670109],
#  [1, 2717, 3.136137522408312],
#  [1, 2571, 4.07319857504623],
#  [1, 1917, 3.461930191513503],
#  [1, 2396, 4.354928387013124],
#  [1, 3735, 4.088671429044683],
#  [1, 1953, 4.245387320631329],
#  [1, 1597, 3.6503513580881797],
#  [1, 3809, 3.571857450892454],
#  [1, 1954, 4.182924188619119],
#  [1, 1955, 4.09650373077192],
#  [1, 235, 3.4441980534486456],
#  [1, 1124, 4.036500305740354],
#  [1, 1957, 4.053453750402739],
#  [1, 163, 3.376586601276193],
#  [1, 21, 3.7090802154015305],
#  [1, 165, 3.7121684736685134],
#  [1, 1090, 4.057333104117493],
#  [1, 380, 3.9420508548272903],
#  [1, 2501, 4.479384971918619],
#  [1, 349, 3.8763579818913407],
#  [1, 457, 4.293896503433966],
#  [1, 1096, 3.8887582361052515],
#  [1, 920, 4.699159902755572],
#  [1, 459, 3.338416805207411],
#  [1, 1527, 3.682891295022422],
#  [1, 3418, 4.260628525759903],
#  [1, 1385, 3.7060371047076908],
#  [1, 3451, 4.054180862372889],
#  [1, 3095, 4.422020643351435],
#  [1, 780, 3.846389892104705],
#  [1, 498, 3.154188104325188],
#  [1, 2728, 4.145163640294642],
#  [1, 2002, 3.470006671229627],
#  [1, 1784, 4.0345694228993505],
#  [1, 2943, 3.903515673916729],
#  [1, 2006, 3.8162671967087447],
#  [1, 318, 4.649383965437473],
#  [1, 1968, 3.8625878569455625],
#  [1, 3678, 3.931972820861367],
#  [1, 1244, 3.828230462322738],
#  [1, 356, 4.255381509543729],
#  [1, 1245, 3.6980914090422194],
#  [1, 3893, 3.572246035051929],
#  [1, 1247, 4.22996595948194],
#  [1, 3421, 4.08458564731694],
#  [1, 1641, 4.128904786459468],
#  [1, 1394, 3.7832296489432435],
#  [1, 3534, 3.5300104046966654],
#  [1, 104, 3.299046646817347],
#  [1, 2735, 3.0890935347538524],
#  [1, 1431, 2.8826770252552847],
#  [1, 3868, 3.885265546159406],
#  [1, 1079, 3.8969181855106734],
#  [1, 2997, 3.835414852005883],
#  [1, 1615, 3.86837159521353],
#  [1, 1291, 4.1437287803262315],
#  [1, 653, 3.3903431243096325],
#  [1, 2167, 3.2669908440607296],
#  [1, 1580, 3.929442535340112],
#  [1, 3619, 3.511075778126682],
#  [1, 1049, 3.528873548362907],
#  [1, 1261, 3.592071344898212],
#  [1, 552, 3.392592584574507],
#  [1, 1266, 3.889361238379634],
#  [1, 733, 4.011316277782042],
#  [1, 1378, 3.428437876671791],
#  [1, 1379, 3.175923571233484],
#  [1, 3552, 3.8885575910354624],
#  [1, 1304, 4.328582533770595],
#  [1, 2470, 3.8030680560527683],
#  [1, 3168, 3.8041943132791185],
#  [1, 2617, 3.4719594416878667],
#  [1, 3671, 4.079323107556125],
#  [1, 2871, 3.9543783436479267],
#  [1, 2115, 3.717345753386453],
#  [1, 1136, 4.149979573628998],
#  [1, 2081, 4.395860000035139],
#  [1, 2951, 3.790544854280357],
#  [1, 1214, 4.338592454486456],
#  [1, 1036, 4.2808683252581],
#  [1, 3702, 3.733180050902754],
#  [1, 2366, 3.7466928990340684],
#  [1, 1387, 4.323671240025],
#  [1, 3527, 3.76909744331271],
#  [1, 1201, 3.858485785696616],
#  [1, 2947, 3.9092044327509887],
#  [1, 1240, 4.309515670112983],
#  [1, 2987, 3.753292808909174],
#  [1, 2333, 3.866529205935466],
#  [1, 1175, 3.597620113979742],
#  [1, 39, 4.091579480889568],
#  [1, 288, 2.9509070668920057],
#  [1, 2337, 3.6317582209782726],
#  [1, 1535, 3.8469095237563846],
#  [1, 1392, 3.8100249134757194],
#  [1, 1466, 3.969513647632257],
#  [1, 860, 3.788671166725402],
#  [1, 1683, 3.8416486521988595],
#  [1, 866, 3.7388332450730974],
#  [1, 1684, 3.7846218260277937],
#  [1, 2770, 3.5697985850011245],
#  [1, 215, 4.106908901820461],
#  [1, 1759, 4.086167656989506],
#  [1, 501, 3.389132806306952],
#  [1, 506, 3.380035637779217],
#  [1, 1250, 4.471249185082016],
#  [1, 3793, 3.7374165900581096],
#  [1, 509, 3.672446533303473],
#  [1, 41, 3.952170070555128],
#  [1, 2058, 3.832348362282243],
#  [1, 3799, 1.9631317620928812],
#  [1, 47, 4.023525598941756],
#  [1, 2700, 3.318024303368441],
#  [1, 296, 4.019928412474066],
#  [1, 581, 4.1430874036525625],
#  [1, 1617, 4.136242715987777],
#  [1, 728, 3.839901378935556],
#  [1, 299, 3.8616275487442704],
#  [1, 3079, 4.107671812378493],
#  [1, 2560, 3.13336642366416],
#  [1, 1909, 3.6654202699682332],
#  [1, 224, 3.6743672883035248],
#  [1, 3728, 4.013574825885063],
#  [1, 229, 3.535427151216954],
#  [1, 6, 3.933406964251837],
#  [1, 3006, 4.254793661030882],
#  [1, 1046, 4.006408329832763],
#  [1, 800, 4.094492217313993],
#  [1, 50, 4.232487875174916],
#  [1, 52, 3.7531905596793678],
#  [1, 1191, 3.441401855907456],
#  [1, 1192, 4.003449769002175],
#  [1, 3081, 3.4974170036963486],
#  [1, 377, 4.1523010120471024],
#  [1, 1268, 3.6794687210825305],
#  [1, 3083, 4.047479856782844],
#  [1, 3513, 3.633195966530092],
#  [1, 2428, 3.2097463930752514],
#  [1, 2282, 3.615807166338265],
#  [1, 3514, 3.335493767220696],
#  [1, 1554, 3.566624933040272],
#  [1, 1912, 3.9611290425178023],
#  [1, 2716, 3.9246178976611894],
#  [1, 1485, 3.744047757827772],
#  [1, 2289, 3.824910245123873],
#  [1, 162, 3.677671790464496],
#  [1, 1127, 3.7774289346006387],
#  [1, 3016, 3.3779279467131564],
#  [1, 2070, 4.010581119585432],
#  [1, 1704, 4.261077168798344],
#  [1, 3163, 3.5473983273694745],
#  [1, 2437, 3.8990726395941984],
#  [1, 2291, 3.5971374695540406],
#  [1, 1635, 3.5476674668668164],
#  [1, 1279, 3.7771707022266687],
#  [1, 2721, 4.0734481542770755],
#  [1, 2723, 2.96556900157113],
#  [1, 1921, 3.3549302584793437],
#  [1, 2725, 3.832825024764673],
#  [1, 1923, 3.879105684803664],
#  [1, 2580, 3.9622350908363435],
#  [1, 3386, 3.8866225823041627],
#  [1, 3744, 3.549408599156375],
#  [1, 968, 3.686261430525097],
#  [1, 896, 3.5390409388785584],
#  [1, 3020, 3.469339117397028],
#  [1, 1788, 3.8669119026089245],
#  [1, 176, 3.965053603461841],
#  [1, 461, 3.421795269393911],
#  [1, 1429, 3.3826455102291395],
#  [1, 2159, 3.4258091760970544],
#  [1, 1715, 3.6515131138116996],
#  [1, 1643, 3.9031951139544097],
#  [1, 3249, 3.788352488793607],
#  [1, 3176, 3.7323165883367015],
#  [1, 1719, 3.7922317620665438],
#  [1, 2806, 3.0632124408678214],
#  [1, 2734, 3.3605136902196753],
#  [1, 1649, 3.847523283597709],
#  [1, 321, 3.9647044076341955],
#  [1, 2013, 3.764095438646113],
#  [1, 3100, 3.8585873656241114],
#  [1, 2952, 3.6886955008164453],
#  [1, 1794, 3.494424192810421],
#  [1, 2599, 3.9203781575178396],
#  [1, 1500, 3.594861556348138],
#  [1, 2959, 3.767089350364647],
#  [1, 1509, 3.7689000727759634],
#  [1, 1722, 3.594113999533008],
#  [1, 1650, 3.6219709176559722],
#  [1, 908, 4.360915091893237],
#  [1, 1653, 3.828349337914041],
#  [1, 2384, 3.5810700419709596],
#  [1, 1729, 3.8169839672368453],
#  [1, 3476, 3.5749274765261307],
#  [1, 2890, 4.00977114943081],
#  [1, 3113, 3.1149816918503364],
#  [1, 16, 3.716487173511838],
#  [1, 2029, 3.9649390513375313],
#  [1, 194, 3.788327058339833],
#  [1, 551, 3.4948122909314985],
#  [1, 1513, 3.521898216622563],
#  [1, 3046, 3.846565048922715],
#  [1, 2318, 3.6171529177848956],
#  [1, 1517, 3.5664900963996793],
#  [1, 1089, 3.6816487582445308],
#  [1, 3260, 3.8138047727495343],
#  [1, 913, 4.348947659374771],
#  [1, 1730, 3.9203667108462317],
#  [1, 3409, 3.651842297389777],
#  [1, 2607, 4.198273096854604],
#  [1, 1449, 3.947298437598621],
#  [1, 1732, 3.136821650936877],
#  [1, 1733, 3.3764433297167464],
#  [1, 2390, 3.724552136963062],
#  [1, 1734, 3.877575986269234],
#  [1, 3266, 3.432552753454762],
#  [1, 3267, 3.6085729731473593],
#  [1, 3624, 3.775775853732852],
#  [1, 2395, 3.3014534397257935],
#  [1, 1594, 3.569215610561836],
#  [1, 2683, 3.4402922058789174],
#  [1, 412, 3.7603590145151546],
#  [1, 2759, 3.6251420497259637],
#  [1, 994, 4.038018045045576],
#  [1, 1884, 2.6478046262281563],
#  [1, 1885, 3.775700536507283],
#  [1, 272, 3.7570258472418296],
#  [1, 24, 3.50012360815552],
#  [1, 3051, 3.4150666719866902],
#  [1, 348, 3.753511320766799],
#  [1, 2323, 4.083678024584862],
#  [1, 1093, 3.5024363856735605],
#  [1, 29, 3.7024800984807142],
#  [1, 562, 3.7901083060072347],
#  [1, 1095, 3.662912050994154],
#  [1, 1529, 3.581081877150438],
#  [1, 2188, 3.1628924292978984],
#  [1, 497, 4.238841941724647],
#  [1, 202, 2.8595618972131085],
#  [1, 1747, 3.5533841059932683],
#  [1, 2908, 4.0889233979631445],
#  [1, 1966, 3.563641879711368],
#  [1, 3499, 4.066953685639328],
#  [1, 353, 3.3006439803980836],
#  [1, 32, 3.6920578477311867],
#  [1, 1243, 3.7126611813179657],
#  [1, 1897, 3.5362385166678147],
#  [1, 1171, 3.549358240014212],
#  [1, 3786, 3.306536100443694],
#  [1, 34, 4.286578130031127],
#  [1, 357, 3.9287777639175667],
#  [1, 36, 4.202541340575671],
#  [1, 714, 3.5797993556710126],
#  [1, 2406, 3.9327530448941985],
#  [1, 1101, 3.9303595978142973],
#  [1, 3717, 3.1869970673919465],
#  [1, 1030, 3.42620927237251],
#  [1, 1688, 3.9838615226085516],
#  [1, 364, 4.272538027886139],
#  [1, 3501, 3.8800126292575503],
#  [1, 3072, 4.242070745155796],
#  [1, 3074, 3.924513517835217],
#  [1, 3508, 4.029771529381858],
#  [1, 1043, 3.2329881208162643],
#  [1, 597, 4.13663416164837],
#  [1, 383, 3.5854130669999074],
#  [1, 2506, 3.7824692110277196],
#  [1, 3524, 3.762452282025697],
#  [1, 1569, 3.949087455253161],
#  [1, 2082, 3.4568184427887707],
#  [1, 3600, 3.316294148388881],
#  [1, 3604, 3.900802451521245],
#  [1, 2802, 3.3694753219258504],
#  [1, 3536, 4.0655108592351885],
#  [1, 3753, 3.8180669483716834],
#  [1, 3682, 3.779641113486025],
#  [1, 2017, 3.396726352324932],
#  [1, 3685, 3.638878757510099],
#  [1, 3610, 2.9376115943417656],
#  [1, 1296, 3.930746713351925],
#  [1, 838, 4.071412870470192],
#  [1, 1007, 3.3406434192924452],
#  [1, 1947, 4.493783860592103],
#  [1, 2966, 4.067487870283135],
#  [1, 266, 3.5628448163925706],
#  [1, 17, 4.37526459162301],
#  [1, 1441, 3.606422549606575],
#  [1, 1088, 3.9518026107322703],
#  [1, 912, 4.5352605858318285],
#  [1, 199, 3.9716268295522124],
#  [1, 1806, 3.2153402132797964],
#  [1, 2469, 3.6676132589488226],
#  [1, 2100, 3.8443541817072253],
#  [1, 1959, 3.871174072290798],
#  [1, 1380, 4.232420193630474],
#  [1, 569, 3.4976262640646527],
#  [1, 1674, 4.24979548886993],
#  [1, 3565, 3.750634751485296],
#  [1, 861, 3.5103574042151133],
#  [1, 1997, 4.08775043432185],
#  [1, 1573, 3.6071387202360854],
#  [1, 474, 4.063961776526795],
#  [1, 1221, 4.299487111472763],
#  [1, 2336, 4.200649393602777],
#  [1, 3425, 3.7660290093976725],
#  [1, 1393, 4.029710102177639],
#  [1, 1682, 3.961313540498667],
#  [1, 508, 4.1343760474213225],
#  [1, 3213, 3.6061552699112838],
#  [1, 42, 3.1466677194562145],
#  [1, 650, 3.8270295280259874],
#  [1, 3500, 3.243544547712154],
#  [1, 3148, 4.098645736307152],
#  [1, 2702, 3.256799547051571],
#  [1, 1476, 3.6189530449706604],
#  [1, 1693, 3.9670233129276555],
#  [1, 151, 3.7095324378918773],
#  [1, 510, 3.1273316688237855],
#  [1, 4, 3.2425405763598243],
#  [1, 1621, 3.6343382556765236],
#  [1, 3155, 3.671207127425648],
#  [1, 58, 4.136022150726072],
#  [1, 2712, 3.228192411678806],
#  [1, 2429, 3.3113643455896655],
#  [1, 1840, 3.67183253220911],
#  [1, 1916, 3.3697410638664933],
#  [1, 1488, 3.3728486336634456],
#  [1, 230, 3.727300696261471],
#  [1, 1120, 3.680216732154013],
#  [1, 161, 3.8157723119274807],
#  [1, 1411, 3.9687679074077797],
#  [1, 524, 3.796835210105877],
#  [1, 1059, 3.647680015895876],
#  [1, 454, 3.9599238543246367],
#  [1, 1701, 3.488128927118571],
#  [1, 1274, 3.641440931735744],
#  [1, 741, 3.816851842889288],
#  [1, 1277, 4.00277620441845],
#  [1, 1639, 3.615793304885303],
#  [1, 3528, 3.4772525315054805],
#  [1, 2297, 3.408602647303232],
#  [1, 465, 3.6026931568006555],
#  [1, 1711, 3.3425276956873957],
#  [1, 538, 3.6859302023161202],
#  [1, 393, 2.478267783791187],
#  [1, 2442, 3.93957031051375],
#  [1, 73, 4.229852747563746],
#  [1, 3246, 4.041741786032193],
#  [1, 3173, 3.323003480513892],
#  [1, 105, 3.524401370471394],
#  [1, 253, 3.605058357845288],
#  [1, 3250, 3.7413397269299806],
#  [1, 3252, 3.752859932766876],
#  [1, 476, 3.1199264982403068],
#  [1, 111, 4.114070258557339],
#  [1, 3259, 3.6937899120280497],
#  [1, 1589, 3.410762314166253],
#  [1, 2023, 3.5795413230798374],
#  [1, 14, 3.8013723246121773],
#  [1, 337, 3.902674943320208],
#  [1, 2314, 3.237881691419254],
#  [1, 2600, 3.3843102731114896],
#  [1, 269, 3.7068234244769513],
#  [1, 555, 3.783156440484072],
#  [1, 1660, 3.752168165158123],
#  [1, 3265, 4.045281631166334],
#  [1, 1735, 3.3339447218629563],
#  [1, 3481, 3.8158925072174794],
#  [1, 2686, 3.956487283631149],
#  [1, 2688, 3.654156611559048],
#  [1, 345, 4.007496721469719],
#  [1, 2320, 3.564271476055054],
#  [1, 25, 3.54120477976264],
#  [1, 2324, 4.406404113714355],
#  [1, 2329, 4.298812784090908],
#  [1, 1810, 3.791483141022276],
#  [1, 2541, 3.4478095979393015],
#  [1, 1673, 3.834243441535646],
#  [1, 1678, 4.126976572859176],
#  [1, 1027, 3.5752663548022108],
#  [1, 2699, 3.224679265301418],
#  [1, 282, 3.6818971045522293],
#  [1, 367, 3.7219698033353836],
#  [1, 223, 3.4585272611007385],
#  [1, 3298, 3.645710433478777],
#  [1, 3948, 3.6938264229864353],
#  [1, 805, 3.932426140129634],
#  [1, 3510, 4.00055080875769],
#  [1, 300, 4.025045146477301],
#  [1, 1777, 3.736861330150832],
#  [1, 3301, 3.6232721100399963],
#  [1, 1343, 3.8839972079082385],
#  [1, 3160, 3.6829661712853086],
#  [1, 529, 4.15482924579473],
#  [1, 3452, 3.417339493026571],
#  [1, 1060, 3.8821880059833633],
#  [1, 1356, 3.749303923500531],
#  [1, 1358, 4.204952558984861],
#  [1, 3178, 4.192524464413447],
#  [1, 3751, 3.7867287296966228],
#  [1, 3826, 3.054181243004702],
#  [1, 3755, 3.7600315706603835],
#  [1, 2302, 4.100511515982784],
#  [1, 1148, 4.437134366635154],
#  [1, 2166, 3.9081874170159434],
#  [1, 3253, 3.571989069175275],
#  [1, 1584, 4.010246865512539],
#  [1, 1223, 4.261619579967125],
#  [1, 1446, 4.0929281583704515],
#  [1, 3623, 3.7040680923178813],
#  [1, 778, 3.653254223301039],
#  [1, 1669, 3.688441692356356],
#  [1, 3484, 3.3288838828907847],
#  [1, 3916, 4.297275475308036],
#  [1, 1233, 4.362541590348419],
#  [1, 1307, 4.323807343573954],
#  [1, 3270, 3.6796803266323304],
#  [1, 1310, 3.846338976682235],
#  [1, 428, 4.068981778313687],
#  [1, 2622, 3.340472185936854],
#  [1, 3358, 3.7579371818574683],
#  [1, 3359, 4.204406916255826],
#  [1, 1756, 3.037916131628659],
#  [1, 1320, 3.386318694862806],
#  [1, 2124, 3.383198807012355],
#  [1, 2125, 4.124183249703151],
#  [1, 2054, 3.531297483029531],
#  [1, 1252, 4.193984937397326],
#  [1, 1254, 4.347727145675836],
#  [1, 3869, 3.362885841753406],
#  [1, 1256, 3.9942133532707396],
#  [1, 1257, 3.940712403618687],
#  [1, 1831, 2.85070602116384],
#  [1, 3363, 4.319761094385556],
#  [1, 586, 3.7634349438290977],
#  [1, 587, 3.9951621312914294],
#  [1, 3438, 3.0740969134290737],
#  [1, 3439, 2.67717574329609],
#  [1, 3296, 4.1341519574158925],
#  [1, 2496, 3.729460131633285],
#  [1, 2497, 3.17329190511097],
#  [1, 2, 3.546833775374252],
#  [1, 2498, 2.7991410657224924],
#  [1, 153, 3.118208619046899],
#  [1, 7, 3.7773348648902547],
#  [1, 2133, 3.8395362513857907],
#  [1, 2135, 3.534368469808031],
#  [1, 2136, 3.4492595774376826],
#  [1, 2137, 4.217927806782772],
#  [1, 802, 3.8614728932434206],
#  [1, 2138, 3.8770794111878013],
#  [1, 1409, 3.4554757274643606],
#  [1, 1339, 3.698531253043589],
#  [1, 1269, 4.2953490757897965],
#  [1, 2640, 3.842095746251838],
#  [1, 592, 3.6458424592695886],
#  [1, 596, 4.2009000251679565],
#  [1, 3447, 4.013723387965702],
#  [1, 1918, 3.4623095449888406],
#  [1, 2140, 3.455983053116149],
#  [1, 2072, 3.0207792820209454],
#  [1, 1271, 4.049679347601829],
#  [1, 1345, 3.9392141017245614],
#  [1, 2077, 3.8384516277068683],
#  [1, 2078, 4.117548377096678],
#  [1, 1276, 4.369061979161965],
#  [1, 743, 2.9952987807395575],
#  [1, 671, 3.6319087504139445],
#  [1, 1278, 4.342700415653655],
#  [1, 3525, 3.380608106566593],
#  [1, 1927, 4.27226463039839],
#  [1, 2657, 3.436159388205031],
#  [1, 3388, 3.2095976917469042],
#  [1, 316, 3.707244953422679],
#  [1, 317, 3.6448489582222106],
#  [1, 248, 3.4383900762397723],
#  [1, 2080, 4.322648762919636],
#  [1, 1282, 4.102097954014335],
#  [1, 1283, 4.156355439208799],
#  [1, 750, 4.325760267843346],
#  [1, 2087, 4.095067073212862],
#  [1, 1286, 4.056873920493119],
#  [1, 3608, 3.543169498650172],
#  [1, 2662, 4.223961439255733],
#  [1, 3466, 3.874439435839709],
#  [1, 2300, 4.010631802217217],
#  [1, 180, 3.2720214557337783],
#  [1, 329, 3.7067312834942583],
#  [1, 3034, 4.0195576159953],
#  [1, 186, 3.390756027383301],
#  [1, 2161, 3.9288004959252696],
#  [1, 3037, 4.219940397070478],
#  [1, 2090, 3.913022358746602],
#  [1, 3039, 3.994585976507998],
#  [1, 2091, 3.57693622641078],
#  [1, 830, 3.4343681039704137],
#  [1, 2093, 3.1410676689089456],
#  [1, 904, 4.602438590143193],
#  [1, 2094, 3.3801367434750924],
#  [1, 1292, 3.928768634113201],
#  [1, 2096, 4.140274353418714],
#  [1, 1294, 4.111453599474631],
#  [1, 765, 3.2198529505637614],
#  [1, 2746, 3.6028317947677624],
#  [1, 1009, 3.809947124740766],
#  [1, 1948, 3.866230246720928],
#  [1, 333, 3.5173635993423824],
#  [1, 339, 4.036127159809708],
#  [1, 2316, 3.3377632514791484],
#  [1, 1371, 3.4362748025355074],
#  [1, 2174, 3.6733307894586162],
#  [1, 1374, 3.856867794170988],
#  [1, 1375, 3.519661845567087],
#  [1, 915, 4.148456489026567],
#  [1, 1376, 3.8254913111743294],
#  [1, 1377, 3.288868153645753],
#  [1, 916, 4.488438605620502],
#  [1, 918, 4.083670164205522],
#  [1, 1012, 4.196065543619645],
#  [1, 2826, 3.1961365990264206],
#  [1, 3629, 4.188994966111432],
#  [1, 1015, 3.8894840364706806],
#  [1, 1016, 3.576610478557042],
#  [1, 1019, 3.911160871671803],
#  [1, 3489, 3.3532996015654097],
#  [1, 344, 3.4007258327940555],
#  [1, 275, 3.089252632447162],
#  [1, 2252, 3.502700283367494],
#  [1, 277, 3.6442160058786417],
#  [1, 923, 4.279040573365388],
#  [1, 924, 4.200536463471007],
#  [1, 3701, 3.614750504885447],
#  [1, 3703, 3.705309727977648],
#  [1, 926, 4.237764023079716],
#  [1, 3704, 3.331490799318821],
#  [1, 1020, 3.7295323161367566],
#  [1, 784, 2.8946676247533074],
#  [1, 858, 4.572249089265236],
#  [1, 1023, 4.264104408930906],
#  [1, 1025, 3.8209165382233063],
#  [1, 2693, 4.126131696375371],
#  [1, 1967, 3.8106151670587014],
#  [1, 351, 3.574017712200395],
#  [1, 2405, 3.4784979281086343],
#  [1, 2407, 4.05313758652105],
#  [1, 3066, 3.837084579361311],
#  [1, 2193, 3.3870382943655284],
#  [1, 932, 4.301402446162275],
#  [1, 1031, 3.8406736414211884],
#  [1, 1104, 4.223268306826033],
#  [1, 1032, 4.055582810589533],
#  [1, 435, 3.149746360462835],
#  [1, 943, 4.190358129472436],
#  [1, 3723, 4.031573876460283],
#  [1, 1042, 3.7208410581596145],
#  [1, 370, 3.3509920240959836],
#  [1, 2423, 3.840254919994348],
#  [1, 3153, 3.557957431723812],
#  [1, 2424, 3.8364442286279483],
#  [1, 3086, 3.782793768008812],
#  [1, 3087, 3.762787870105474],
#  [1, 953, 4.627641716135809],
#  [1, 954, 4.373694434480416],
#  [1, 3591, 3.738049733977869],
#  [1, 2863, 3.8135979902169237],
#  [1, 3593, 2.061625362147899],
#  [1, 1125, 4.046450319560398],
#  [1, 520, 3.006048467520224],
#  [1, 3668, 4.205963929621047],
#  [1, 2795, 3.9136295121405738],
#  [1, 1129, 3.395768326972313],
#  [1, 2431, 3.45898576381845],
#  [1, 62, 4.086441114476936],
#  [1, 3309, 3.849259139322972],
#  [1, 1633, 3.622706132674042],
#  [1, 2436, 3.8539265090609285],
#  [1, 3097, 4.116923612449762],
#  [1, 3099, 3.4377863445875083],
#  [1, 3812, 3.7166355526722503],
#  [1, 2000, 4.085678416345419],
#  [1, 963, 3.7557159542631258],
#  [1, 2001, 3.817214227675674],
#  [1, 1200, 4.205884889303032],
#  [1, 2003, 3.3817776344777752],
#  [1, 1203, 4.395458208767659],
#  [1, 2005, 3.5204396811514647],
#  [1, 1204, 4.408525651758958],
#  [1, 969, 4.468532248378247],
#  [1, 2872, 3.8144965067335965],
#  [1, 3675, 4.268862512084681],
#  [1, 2946, 3.9156756520278524],
#  [1, 898, 4.474847768987405],
#  [1, 2009, 3.779537795098564],
#  [1, 2874, 3.9317618648000687],
#  [1, 899, 4.462353929212218],
#  [1, 1135, 3.6561980758419286],
#  [1, 2948, 3.9635211025217982],
#  [1, 539, 4.182886381760048],
#  [1, 2371, 3.4873272792722982],
#  [1, 3247, 3.7953491877989265],
#  [1, 3174, 3.3764629833615256],
#  [1, 3175, 3.913566622263576],
#  [1, 2375, 3.263796741829911],
#  [1, 2378, 3.3797044645951275],
#  [1, 971, 4.121731202595152],
#  [1, 2011, 3.683673216370665],
#  [1, 2012, 3.4526700276857447],
#  [1, 2015, 3.906464575981571],
#  [1, 1215, 3.5205860235538244],
#  [1, 1073, 3.9681977692174994],
#  [1, 3688, 3.1489327900591957],
#  [1, 541, 4.185007768228687],
#  [1, 542, 3.2922834226003217],
#  [1, 543, 3.5052540226648103],
#  [1, 3254, 3.11528936068327],
#  [1, 2453, 3.5641851787526293],
#  [1, 2529, 3.649422766221131],
#  [1, 1654, 3.785846920357052],
#  [1, 1583, 3.259734843108966],
#  [1, 3189, 3.998535143072951],
#  [1, 116, 4.324528529394582],
#  [1, 1586, 3.4625398171284485],
#  [1, 2021, 3.4797290228186055],
#  [1, 1220, 3.9082655460766125],
#  [1, 1080, 3.9117237024796543],
#  [1, 2967, 3.8585853949762834],
#  [1, 2968, 3.56168647899652],
#  [1, 2530, 3.3094313275969864],
#  [1, 3264, 3.551176550926604],
#  [1, 3194, 3.7276581144037664],
#  [1, 2393, 3.6386767848712567],
#  [1, 3198, 4.203551595812094],
#  [1, 2399, 3.105301825846397],
#  [1, 1302, 4.1510779221743626],
#  [1, 1230, 3.9928144305199718],
#  [1, 2105, 3.2961203589789885],
#  [1, 2033, 3.4368567896090827],
#  [1, 2108, 3.757614823458314],
#  [1, 1234, 4.399189466059325],
#  [1, 2109, 3.6109844850739035],
#  [1, 1091, 3.1286628335550244],
#  [1, 3347, 4.133198696010252],
#  [1, 203, 3.5153497077975757],
#  [1, 1676, 3.2557461479663723],
#  [1, 208, 3.042092240906015],
#  [1, 2111, 3.435255933704079],
#  [1, 2040, 3.3661059218581686],
#  [1, 2041, 3.2415217342471494],
#  [1, 3928, 3.541681426412664],
#  [1, 2043, 3.5622576510480286],
#  [1, 2045, 3.745366642193998],
#  [1, 2046, 3.9666114776497037],
#  [1, 2047, 3.4786616879686414],
#  [1, 2049, 3.4854596368732174],
#  [1, 1753, 2.922077404088069],
#  [1, 216, 3.077782526951867],
#  [1, 2706, 3.7116107576394355],
#  [1, 2639, 3.5068002223440073],
#  [1, 2710, 2.8667028277389486],
#  [1, 663, 3.302758245936447],
#  [1, 3448, 3.8235039873862715],
#  [1, 231, 3.409499497435933],
#  [1, 2076, 3.585112060782496],
#  [1, 246, 4.354870939961614],
#  [1, 249, 4.170733020918125],
#  [1, 1288, 3.910544129449685],
#  [1, 3396, 3.853235657781367],
#  [1, 3101, 4.002835026163773],
#  [1, 2598, 3.4263946842341952],
#  [1, 2306, 2.99385062125839],
#  [1, 764, 3.695925342604054],
#  [1, 342, 3.8780742140564564],
#  [1, 1887, 2.7973153617084057],
#  [1, 2325, 3.215212328346289],
#  [1, 3129, 3.620309164929527],
#  [1, 2907, 2.7531586134612],
#  [1, 788, 3.478386534618004],
#  [1, 2766, 3.6687246449245383],
#  [1, 2335, 3.0145823670695835],
#  [1, 1461, 3.1010592786935867],
#  [1, 3146, 2.715580872626167],
#  [1, 1546, 3.9135670183026736],
#  [1, 440, 4.0571034591647],
#  [1, 441, 3.60529102263231],
#  [1, 2507, 3.3786056227497605],
#  [1, 1563, 3.8295960222726126],
#  [1, 1498, 3.493132043996824],
#  [1, 2883, 3.6448567790361373],
#  [1, 3182, 3.8540649760145067],
#  [1, 85, 3.6443270585528635],
#  [1, 88, 3.315096349167135],
#  [1, 986, 4.090033546750631],
#  [1, 481, 3.1755178561960182],
#  [1, 2539, 3.64171830656594],
#  [1, 1665, 3.136455682087928],
#  [1, 2106, 3.755680676354288],
#  [1, 708, 3.8310097190503325],
#  [1, 3362, 3.9322189732373967],
#  [1, 813, 3.121585876115982],
#  [1, 3897, 4.124900448072769],
#  [1, 934, 4.1767594235077805],
#  [1, 3658, 3.8893482624424798],
#  [1, 1303, 4.091681852976458],
#  [1, 999, 3.4316917764393304],
#  [1, 2616, 3.2245551190915522],
#  [1, 3785, 3.28809912145848],
#  [1, 1331, 3.587029200284014],
#  [1, 1262, 4.436712634633078],
#  [1, 2641, 3.5393987233042052],
#  [1, 3036, 3.392448992152209],
#  [1, 3479, 3.9014816826966503],
#  [1, 10, 3.6323235626991983],
#  [1, 2822, 3.3007078096347824],
#  [1, 3494, 3.815054395660926],
#  [1, 421, 3.8306500602578],
#  [1, 3070, 3.432402203608895],
#  [1, 2414, 3.5739832255283077],
#  [1, 1479, 3.469473732836188],
#  [1, 517, 3.43021508542059],
#  [1, 952, 3.883438138616935],
#  [1, 60, 3.615069946654347],
#  [1, 3745, 3.49228777310101],
#  [1, 2370, 3.7676455783311398],
#  [1, 1216, 3.7592248704689673],
#  [1, 2528, 3.714314308264794],
#  [1, 1587, 3.19894876114515],
#  [1, 3269, 3.591285058330404],
#  [1, 3417, 3.9926876703650347],
#  [1, 3354, 2.9352103986004074],
#  [1, 1263, 4.100047120434337],
#  [1, 2572, 3.7116847212607813],
#  [1, 2731, 4.167548562836064],
#  [1, 3033, 3.2458654275928076],
#  [1, 2243, 3.9143337593719907],
#  [1, 2694, 3.425784027619074],
#  [1, 2920, 4.075941342913296],
#  [1, 1982, 3.7702741923875145],
#  [1, 2976, 2.8594386597745673],
#  [1, 2485, 3.5535846253254744],
#  [1, 141, 3.973437092567352],
#  [1, 3798, 3.833324705300892],
#  [1, 2707, 3.9485238573507315],
#  [1, 2567, 3.5726072715075983],
#  [1, 3004, 2.915764470928958],
#  [1, 3005, 3.799533032785103],
#  [1, 2719, 2.871829441737114],
#  [1, 160, 2.9694037656378436],
#  [1, 748, 3.6293297046964037],
#  [1, 2724, 3.593782282390773],
#  [1, 2581, 3.689125996741759],
#  [1, 1783, 3.575592703524197],
#  [1, 1422, 3.4884287921736092],
#  [1, 3461, 3.7880569165999263],
#  [1, 3535, 3.050400508436283],
#  [1, 257, 3.722953342393187],
#  [1, 832, 3.8064680261600037],
#  [1, 762, 2.6444872180062626],
#  [1, 2676, 3.5854006810742076],
#  [1, 1883, 3.661327178069998],
#  [1, 2763, 3.9862486330237323],
#  [1, 3566, 3.2932751522019843],
#  [1, 2764, 3.8082773172905107],
#  [1, 1892, 3.784506989284806],
#  [1, 1608, 3.8855859522480243],
#  [1, 1396, 3.8452244984948516],
#  [1, 2840, 3.1718570011623686],
#  [1, 2841, 3.9938026480739595],
#  [1, 3646, 3.04466842384882],
#  [1, 500, 3.912784006720786],
#  [1, 3145, 3.356875969611976],
#  [1, 2272, 3.7794604204757722],
#  [1, 2273, 3.639671399701434],
#  [1, 1619, 3.616452260059352],
#  [1, 1625, 3.9213263201187782],
#  [1, 1487, 3.723570083953283],
#  [1, 1702, 2.975759785809116],
#  [1, 2433, 3.8343076543642134],
#  [1, 70, 3.0115302451369477],
#  [1, 1644, 3.282370077629258],
#  [1, 1645, 3.700838114919141],
#  [1, 2882, 3.413656017768224],
#  [1, 2387, 2.9684116472870947],
#  [1, 2389, 3.149416013662806],
#  [1, 2961, 3.381963894782115],
#  [1, 553, 3.925302341497302],
#  [1, 628, 4.310893086299328],
#  [1, 3261, 3.652687036069178],
#  [1, 2605, 3.504994336574351],
#  [1, 1804, 3.429503724293825],
#  [1, 1805, 3.7439327815110293],
#  [1, 2391, 3.8732161979472544],
#  [1, 2394, 3.973487158386459],
#  [1, 3773, 3.230012212136725],
#  [1, 1092, 3.86080069154298],
#  [1, 1672, 3.849947175061082],
#  [1, 2555, 2.1302250846329596],
#  [1, 2629, 2.9885091218074717],
#  [1, 2701, 2.550527733967777],
#  [1, 2568, 2.577653222376593],
#  [1, 2713, 2.8335068663600467],
#  [1, 1911, 3.2333730598319197],
#  [1, 3516, 3.825562390923165],
#  [1, 2643, 2.522874733115886],
#  [1, 2720, 2.6167539195223712],
#  [1, 2722, 3.247620177093846],
#  [1, 2805, 3.30140068533809],
#  [1, 2828, 2.64798723867009],
#  [1, 2761, 4.100840284867798],
#  [1, 2856, 3.125510210209139],
#  [1, 2369, 3.340801213943112],
#  [1, 2888, 3.309359657299637],
#  [1, 2392, 2.8149039932294575],
#  [1, 2975, 3.554608947581684],
#  [1, 1179, 3.83253443080639],
#  [1, 2553, 3.4332710661021424],
#  [1, 2554, 3.3993763462785953],
#  [1, 3932, 3.7259187799798026],
#  [1, 3863, 3.4752937977655276],
#  [1, 1185, 4.028523040730044],
#  [1, 3503, 3.6490525983001048],
#  [1, 3879, 3.07838662921689],
#  [1, 3375, 3.686282194466937],
#  [1, 1779, 2.987562490248824],
#  [1, 164, 3.506236535764856],
#  [1, 3457, 3.3045143604113223],
#  [1, 319, 4.075861155090684],
#  [1, 247, 3.6842248806922115],
#  [1, 1428, 3.6560335115828844],
#  [1, 1284, 4.156407791362298],
#  [1, 2660, 3.995640126663791],
#  [1, 2661, 3.513481102250967],
#  [1, 2663, 3.2864783517776552],
#  [1, 2664, 3.995630630964791],
#  [1, 2667, 2.8601822739403184],
#  [1, 2668, 2.9137059026392866],
#  [1, 3032, 3.7939179856038],
#  [1, 2311, 3.564682322575073],
#  [1, 2173, 3.6245809036747803],
#  [1, 198, 3.4458239843117893],
#  [1, 2752, 3.503122873037447],
#  [1, 340, 3.618684979968336],
#  [1, 3700, 3.5324223971639004],
#  [1, 2901, 3.2574138059496067],
#  [1, 3638, 3.4934373155444156],
#  [1, 30, 3.710204259047482],
#  [1, 1601, 3.3830364672016087],
#  [1, 3713, 4.011716307859618],
#  [1, 2912, 3.494884195156546],
#  [1, 3576, 3.8292576525997375],
#  [1, 503, 3.745711401040663],
#  [1, 293, 4.022138090532567],
#  [1, 1614, 3.7038701270872263],
#  [1, 2346, 3.5572710187711456],
#  [1, 942, 4.240799328692066],
#  [1, 446, 4.091952245726803],
#  [1, 1624, 3.275612625885049],
#  [1, 3156, 3.175324277229081],
#  [1, 2287, 3.755743125386646],
#  [1, 2288, 3.8219718572666963],
#  [1, 3662, 2.8456241547124757],
#  [1, 3594, 3.780440338169224],
#  [1, 3300, 3.3793643159352085],
#  [1, 1206, 3.79961142937413],
#  [1, 1069, 3.975325301441266],
#  [1, 76, 3.125865307600729],
#  [1, 2377, 3.4830530903669086],
#  [1, 2010, 3.9926620218240636],
#  [1, 3827, 3.603264794656605],
#  [1, 610, 3.642142281236939],
#  [1, 1077, 4.111808061463829],
#  [1, 2526, 2.7004753941924102],
#  [1, 2527, 3.7002308987673564],
#  [1, 2454, 3.692235297416681],
#  [1, 2455, 3.713439421372781],
#  [1, 3696, 3.0294076256937696],
#  [1, 2533, 3.28834500783227],
#  [1, 1301, 4.158836735509808],
#  [1, 707, 3.6055335491904383],
#  [1, 2613, 3.438658575912923],
#  [1, 2542, 3.710324750858469],
#  [1, 496, 3.2976822563404697],
#  [1, 2549, 2.9350136290673747],
#  [1, 1748, 3.656067260966123],
#  [1, 3927, 3.7501828602336733],
#  [1, 2116, 3.355401488505867],
#  [1, 2117, 3.7338217071231004],
#  [1, 2985, 3.7242445921513307],
#  [1, 2989, 3.567294512060274],
#  [1, 2123, 3.3471204820838016],
#  [1, 2052, 3.29381036386596],
#  [1, 2993, 3.741154724339309],
#  [1, 1186, 3.613865349692549],
#  [1, 222, 3.711771036994831],
#  [1, 158, 3.3164359965271415],
#  [1, 3877, 2.54666021231443],
#  [1, 2139, 3.911698469284037],
#  [1, 3440, 2.4133336825723535],
#  [1, 737, 2.317764870284815],
#  [1, 2718, 3.3475551429305725],
#  [1, 2573, 3.5051560481680295],
#  [1, 302, 3.953886342667203],
#  [1, 232, 4.114911461455313],
#  [1, 2141, 3.7678855605558357],
#  [1, 2142, 3.4158941242545953],
#  [1, 168, 3.627826747263082],
#  [1, 2143, 3.341288737532865],
#  [1, 2145, 3.648452086308995],
#  [1, 1344, 3.9129562658241803],
#  [1, 3889, 2.591270476520468],
#  [1, 1275, 3.7120520351601702],
#  [1, 3526, 4.020798296095152],
#  [1, 313, 3.344939522077228],
#  [1, 2153, 2.354153894653855],
#  [1, 2083, 3.8399968115580583],
#  [1, 2085, 4.16045540145026],
#  [1, 2089, 3.581388476775876],
#  [1, 2807, 2.3846725724334044],
#  [1, 2739, 4.087660749430539],
#  [1, 3397, 3.7619318561606345],
#  [1, 3398, 3.63808999895923],
#  [1, 3399, 3.335023609996443],
#  ...]

# %%
df_main_cols = df[["user", "item", "rating"]]

# %%
df_main_cols
# Out:
#          user  item  rating
# 0           1  1193       5
# 1           1   661       3
# 2           1   914       3
# 3           1  3408       4
# 4           1  2355       5
# ...       ...   ...     ...
# 1000204  6040  1091       1
# 1000205  6040  1094       5
# 1000206  6040   562       5
# 1000207  6040  1096       4
# 1000208  6040  1097       4
#
# [1000209 rows x 3 columns]

# %%
predictions_df = pd.DataFrame(processed_predictions, columns=df_main_cols.columns)
df_filled = pd.concat([df_main_cols, predictions_df], ignore_index=True)

# %%
df_filled
# Out:
#           user  item    rating
# 0            1  1193  5.000000
# 1            1   661  3.000000
# 2            1   914  3.000000
# 3            1  3408  4.000000
# 4            1  2355  5.000000
# ...        ...   ...       ...
# 22384235  6040  2198  2.990271
# 22384236  6040  2703  3.182332
# 22384237  6040  2845  3.090408
# 22384238  6040  3607  3.034246
# 22384239  6040  2909  3.097572
#
# [22384240 rows x 3 columns]

# %% [markdown]
# ## Sanity check
#
# Lets check if every user has exactly M items in its rating matrix entry

# %%
M = len(df_main_cols['item'].unique())

# %%
sanity_check = df_filled.groupby("user").size().reset_index().rename(columns={0: "rated_items"})

# %%
sanity_check
# Out:
#       user  rated_items
# 0        1         3706
# 1        2         3706
# 2        3         3706
# 3        4         3706
# 4        5         3706
# ...    ...          ...
# 6035  6036         3706
# 6036  6037         3706
# 6037  6038         3706
# 6038  6039         3706
# 6039  6040         3706
#
# [6040 rows x 2 columns]

# %%
sanity_check[sanity_check["rated_items"] != M]
# Out:
# Empty DataFrame
# Columns: [user, rated_items]
# Index: []

# %% [markdown]
# ## Saving the filled out preference matrix

# %%
df_filled.to_csv("../data/simulation/movielens_1m_sinthetically_filled.csv")

# %%
df_filled.to_pickle("../data/simulation/movielens_1m_sinthetically_filled.pkl")
