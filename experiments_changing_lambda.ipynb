# %%
from dynamicTasteDistortion.scripts.vis import plot_metric_comparison

# %% [markdown]
# ## Analysis of varying lambda for movielens

# %%
def load_experiments(dataset):
    base_path = f"experiments/evolving_preferences_{dataset}"
    calibrated_base_path = f"{base_path}/bpr_unbiased_calibrated"
    uncalibrated_base_path = f"{base_path}/bpr_unbiased_uncalibrated"
    
    _lambdas = [l for l in range(1, 10)]
    
    calibrated_exps = [f"{calibrated_base_path}_alpha_0_{_lambda}.yaml" for _lambda in _lambdas]
    uncalibrated_exps = [f"{uncalibrated_base_path}_alpha_0_{_lambda}.yaml" for _lambda in _lambdas]
    
    return calibrated_exps, uncalibrated_exps

calibrated_exps, uncalibrated_exps = load_experiments("movielens")
calibrated_exps_yelp, uncalibrated_exps_yelp = load_experiments("yelp")

# %%
_lambdas = [l for l in range(1, 10)]
exp_names = [f"$\\alpha={l/10}$" for l in _lambdas]

# %%
from dynamicTasteDistortion.scripts.vis import FULL_PAGE_FIG_SIZE

# %% [markdown]
# ### Distortion related

# %%
plot_metric_comparison(uncalibrated_exps,  metric_name="diver", title="Movielens Based Simulation", graph="box", plot_retrain_points=True,  window_size=5, experiment_aliases=exp_names)

# %%
plot_metric_comparison(calibrated_exps,  metric_name="diver", title="Movielens Based Simulation", graph="box", plot_retrain_points=True,  window_size=5, experiment_aliases=exp_names)

# %%
plot_metric_comparison(calibrated_exps_yelp,  metric_name="diver", title="Yelp Based Simulation", graph="box", plot_retrain_points=True,  window_size=5, experiment_aliases=exp_names)

# %%
plot_metric_comparison(uncalibrated_exps_yelp,  metric_name="diver", title="", graph="box", plot_retrain_points=True,  window_size=5,experiment_aliases=exp_names)

# %%
plot_metric_comparison(calibrated_exps,  metric_name="mace", title="Movielens Based Simulation", graph="box", plot_retrain_points=True,  window_size=5, experiment_aliases=exp_names)

# %%
plot_metric_comparison(calibrated_exps_yelp,  metric_name="mace", title="Movielens Based Simulation", graph="box", plot_retrain_points=True,  window_size=5, experiment_aliases=exp_names)

# %% [markdown]
# ### fairness related

# %%
plot_metric_comparison(uncalibrated_exps,  metric_name="div", title="", graph="box", plot_retrain_points=True,  window_size=5, experiment_aliases=exp_names)

# %%
plot_metric_comparison(calibrated_exps,  metric_name="div", title="", graph="box", plot_retrain_points=True,  window_size=5, experiment_aliases=exp_names)

# %%
plot_metric_comparison(uncalibrated_exps_yelp,  metric_name="div", title="", graph="box", plot_retrain_points=True,  window_size=5, experiment_aliases=exp_names)

# %%
plot_metric_comparison(calibrated_exps_yelp,  metric_name="div", title="", graph="box", plot_retrain_points=True,  window_size=5, experiment_aliases=exp_names)

# %%
plot_metric_comparison(calibrated_exps,  metric_name="coverage", title="", graph="box", plot_retrain_points=True,  window_size=5, experiment_aliases=exp_names)

# %%
plot_metric_comparison(calibrated_exps_yelp,  metric_name="coverage", title="", graph="box", plot_retrain_points=True,  window_size=5, experiment_aliases=exp_names)
